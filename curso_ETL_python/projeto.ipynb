# %% [markdown]
# <h1>Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Inicialização-do-Projeto" data-toc-modified-id="Inicialização-do-Projeto-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Inicialização do Projeto</a></span></li></ul></div>

# %% [markdown]
# ## Inicialização do Projeto

# %%
import pandas as pd
import pandera as pa

# %%
# df = pd.read_csv(infile, parse_dates=['datetime'], date_parser=dateparse)
# dateparse = lambda x: pd.datetime.strptime(x, '%d/%m/%Y')
df = pd.read_csv("ocorrencia_2010_2020.csv", parse_dates=['ocorrencia_dia'], dayfirst=True)
# df['ocorrencia_dia'] = pd.to_datetime(df.ocorrencia_dia)
# df = df.drop('Unnamed: 9', axis=1)
# df = df.drop('Unnamed: 10', axis=1)
# df.head(10)
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Com o uso do Pandera é possível validarmos nossos dados, se são dos tipos esperados e outras coisas, para confirmar que estamos trabalhando com os dados íntegros.
# Estudar mais de expressão regulares
schema = pa.DataFrameSchema(
    columns = {
        "codigo": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes

# %%
df.ocorrencia_dia.dt.month  # CORRIGIDO: (PROBLEMA COM ALGUNS DADOS DIVERGENTE NA COLUNA)Rever o type da coluna ocorrencia_dia pois não está convertendo para datetime
