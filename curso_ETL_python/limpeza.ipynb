# %% [markdown]
# <h1>Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
# Localizar um dado especifico, através do indice e coluna
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5735         MANOEL URBANO
# 5736              CAMPINAS
# 5737     LAGOA DA CONFUSÃO
# 5738        RIO DE JANEIRO
# 5739             VICENTINA
# Name: ocorrencia_cidade, Length: 5740, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.ocorrencia_uf.is_unique
# Out:
# False

# %%
# Alterar o indice do dataframe para ser pelo codigo_ocorrencia
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df.loc[39527]
# Out:
# codigo_ocorrencia2                        39527
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade            LUCAS DO RIO VERDE
# ocorrencia_uf                                MT
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2010-01-04 00:00:00
# ocorrencia_hora                        17:30:00
# total_recomendacoes                           0
# Name: 39527, dtype: object

# %%
# Reverter a alteração do indice.
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
# Alterar um valor de uma coluna x indice
df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
#
#    total_recomendacoes
# 0                    0

# %%
# Alterar os dados de toda uma linha
# df.loc[1] = 20
# Alterar os dados de uma coluna
# df[:, 'total_recomendacoes'] = 10

# %%
# Realizar o backup de uma coluna

# df['ocorrencia_bkp'] = df.ocorrencia_df

# %%
# Realizar a alteração de dados de uma coluna se a condição for válida

# df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'INCIDENTE GRAVE'

# %%
# df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BELÉM
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5735               79769          INCIDENTE GRAVE       MANOEL URBANO
# 5736               79804          INCIDENTE GRAVE            CAMPINAS
# 5737               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5738               79802                INCIDENTE      RIO DE JANEIRO
# 5739               79756          INCIDENTE GRAVE           VICENTINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Pesquisa de um filtro específico
# df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 11                 40069          INCIDENTE GRAVE         SÃO PAULO
# 16                 39809          INCIDENTE GRAVE         SÃO PAULO
# 18                 39828          INCIDENTE GRAVE            SANTOS
# 26                 39847          INCIDENTE GRAVE          SOROCABA
# 27                 39768          INCIDENTE GRAVE          CAMPINAS
# ...                  ...                      ...               ...
# 5694               79739          INCIDENTE GRAVE         SÃO PAULO
# 5695               79705          INCIDENTE GRAVE          SOROCABA
# 5705               79718          INCIDENTE GRAVE         SÃO PAULO
# 5731               79800          INCIDENTE GRAVE         SÃO PAULO
# 5736               79804          INCIDENTE GRAVE          CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 11              SP                 SBMT     2010-01-10        14:50:00
# ...

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BELÉM
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5735               79769          INCIDENTE GRAVE       MANOEL URBANO
# 5736               79804          INCIDENTE GRAVE            CAMPINAS
# 5737               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5738               79802                INCIDENTE      RIO DE JANEIRO
# 5739               79756          INCIDENTE GRAVE           VICENTINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# ...                 ...                 ...                      ...
# 5694              79739               79739          INCIDENTE GRAVE
# 5695              79705               79705          INCIDENTE GRAVE
# 5705              79718               79718          INCIDENTE GRAVE
# 5731              79800               79800                INCIDENTE
# 5736              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %% [raw]
# ocorrencia_uf
# ***
#
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
#
#
# ocorrencia_hora
# NULL

# %%
df.replace(['**', '***', '###!', '####', '****', '*****', 'NULL'], pd.NA, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5735      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5736           CAMPINAS            SP                 SBKP     2020-12-29
# 5737  LAGOA DA CONFUSÃO            TO                 <NA>     2020-12-30
# 5738     RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5739          VICENTINA            MS                 <NA>     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5735        18:30:00                    0
# ...

# %%
df.isna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2  ocorrencia_classificacao  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                 False               False                     False
# ...                 ...                 ...                       ...
# 5735              False               False                     False
# 5736              False               False                     False
# 5737              False               False                     False
# 5738              False               False                     False
# 5739              False               False                     False
#
#       ocorrencia_cidade  ocorrencia_uf  ocorrencia_aerodromo  ocorrencia_dia  \
# ...

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2343
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2343
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# df.fillna(0)

# %%
# df.fillna(value={"total_recomendacoes":10}, inplace=Ture)  # inplace faz a persistencia de mudança do dataframe

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
# 5740              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Exclui do dataframe as informacoes duplicadas
df = df.drop_duplicates()

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5735              79769               79769          INCIDENTE GRAVE
# 5736              79804               79804                INCIDENTE
# 5737              79757               79757          INCIDENTE GRAVE
# 5738              79802               79802                INCIDENTE
# 5739              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5735      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5736           CAMPINAS            SP                 SBKP     2020-12-29
# 5737  LAGOA DA CONFUSÃO            TO                 ****     2020-12-30
# 5738     RIO DE JANEIRO            RJ                 SBGL     2020-12-30
# 5739          VICENTINA            MS                 ****     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 5735        18:30:00                    0
# ...
